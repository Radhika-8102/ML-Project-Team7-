# %% [markdown]
# Data Classification

# %% [markdown]
# ![image.png](attachment:66ab3614-b847-4574-8a99-c4e3b5b6075c.png)

# %% [markdown]
# ![image.png](attachment:b83aeadf-a4fd-4d6f-8e50-2854d6eaacbf.png)

# %% [markdown]
# 1. Trim leading & trailing white spaces
# 2. Inspect the column & data types
# 3. Drop unwanted columns
# 4. Change any data types if needed
# 5. Check for missing data
# 6. Calculate the % of ng

# %% [markdown]
# Less than 5% missing data is often considered safe to discard or impute.

# %% [markdown]
# ![image.png](attachment:0b8d265b-e057-4935-969d-05b12e110253.png)

# %% [markdown]
# ![image.png](attachment:231c4502-5d07-42fc-a55d-e3c79a7f6129.png)

# %% [markdown]
# ![image.png](attachment:0a155f36-337e-43b9-b376-e6cc6d7096ba.png)

# %% [markdown]
# 7. Inspect the features before cleaning

# %% [markdown]
# ![image.png](attachment:ba2b6768-1a6f-4e13-8de8-3af62a28d858.png)
